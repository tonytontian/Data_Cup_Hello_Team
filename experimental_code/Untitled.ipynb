# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv("../data/facturation_train.csv").head(100)
# Out:
#      ID_CPTE PERIODID_MY StatementDate  CurrentTotalBalance  CashBalance  \
# 0   99690111  2015-05-01    2015-05-03              8497.84      4293.12
# 1   99690111  2014-11-01    2014-11-03               866.00         0.00
# 2   99690111  2015-06-01    2015-05-31             10790.95      5224.44
# 3   99690111  2015-10-01    2015-10-04             12388.46      4786.08
# 4   99690111  2015-11-01    2015-11-02             12746.50      4818.48
# 5   99690111  2015-08-01    2015-08-02             10610.05      4753.35
# 6   99690111  2015-09-01    2015-08-30             11417.12      4616.46
# 7   99690111  2014-12-01    2014-12-03              1151.85         0.00
# 8   99690111  2015-02-01    2015-01-31              4045.67      1148.45
# 9   99690111  2015-12-01    2015-11-30             13119.60      4791.44
# 10  99690111  2015-01-01    2015-01-02              2298.96       350.00
# 11  99690111  2015-03-01    2015-03-03              5926.20      2567.25
# ...

# %%
pd.read_csv("../data/performance_train.csv").shape
# Out:
# (11900, 3)

# %%
pd.read_csv("../data/paiements_train.csv").head(50)
# Out:
#      ID_CPTE  TRANSACTION_AMT     TRANSACTION_DTTM PAYMENT_REVERSAL_XFLG
# 0   99690111           208.00  2015-04-26 00:00:00                     Q
# 1   99690111           176.80  2015-05-28 00:00:00                     Q
# 2   99690111           200.00  2015-03-27 04:00:00                     Q
# 3   99690111            80.80  2015-04-02 00:00:00                     Q
# 4   99690111           250.00  2015-11-24 00:00:00                     Q
# 5   99690111           273.00  2015-12-26 00:00:00                     Q
# 6   99690111           267.50  2015-08-23 00:00:00                     Q
# 7   99690111           618.00  2015-07-27 00:00:00                     Q
# 8   99690111           226.60  2015-09-30 00:00:00                     Q
# 9   99690111           244.80  2015-10-27 00:00:00                     Q
# 10  99690111           303.00  2015-06-25 00:00:00                     Q
# 11  99690111           303.00  2015-02-26 00:00:00                     Q
# ...

# %%
transactions_train = pd.read_csv("../data/transactions_train.csv")
transactions_test = pd.read_csv("../data/transactions_test.csv")

# %%
transactions_train.shape
# Out:
# (690730, 11)
